# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from nltk.corpus import stopwords
from nltk.util import ngrams

from sklearn.feature_extraction.text import CountVectorizer
import gensim
from collections import  Counter
import string
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.tokenize import word_tokenize
import pyLDAvis
from wordcloud import WordCloud, STOPWORDS
from textblob import TextBlob
from spacy import displacy
import nltk
from textblob import TextBlob
from textstat import flesch_reading_ease

plt.rcParams.update({'font.size': 18})
plt.rcParams.update({'figure.figsize': [16, 12]})
plt.style.use('seaborn-whitegrid')


# In[ ]:


class vizzy_sentence:
    def __init__(self, data, column, label):
        from nltk.corpus import stopwords
        stopwords = set(stopwords.words('english'))
        data[column] = data[column].apply(lambda x: x.lower())
        data['text_without_stopwords'] = data[column].apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in stopwords]))
        self.data = data
        self.column = column
        
        
    def show_char_count(self):
        '''Histogram of the length of your data column in characters'''
        char_plot = self.data[self.column].str.len().hist()
        return char_plot
    
    def show_word_count(self):
        '''Histogram of the length of data column in words'''
        count_plot = self.data[self.column].str.split().map(lambda x: len(x)).hist()
        return count_plot
    
    def show_word_length(self):
        '''Hist of length of words in data column in characters'''
        len_plot = self.data[self.column].str.split().apply(lambda x : [len(i) for i in x]).map(lambda x: np.mean(x)).hist()
        return len_plot
    
    def show_common_stopwords(self):
        '''List of common stopwords in data'''
        stop=set(STOPWORDS)
        corpus=[]
        new= self.data[self.column].str.split()
        new=new.values.tolist()
        corpus=[word for i in new for word in i]

        from collections import defaultdict
        dic=defaultdict(int)
        for word in corpus:
            if word in STOPWORDS:
                dic[word]+=1
        top=sorted(dic.items(), key=lambda x:x[1],reverse=True)[:10] 
        x,y=zip(*top)
        plot = plt.bar(x,y)
        return plot
    
    def show_common_words(self):
        '''Common words in data'''
        corpus=[]
        new=self.data[self.column].str.split()
        new=new.values.tolist()
        corpus=[word for i in new for word in i]
        counter=Counter(corpus)
        most=counter.most_common()
        x, y=[], []
        for word,count in most[:40]:
            try:
                if (word not in STOPWORDS):
                    x.append(word)
                    y.append(count)
            except:
                x.append(word)
                y.append(count)
        sns.barplot(x=y,y=x)
        
    def show_sentiment(self):
        '''Sentiment in data'''
        text = self.data[self.column]
        def polarity(text):
            return TextBlob(text).sentiment.polarity
        self.data['polarity_score']=self.data[self.column].apply(lambda x : polarity(x))
        hist = self.data['polarity_score'].hist()
        return hist

    def show_sentiment_cats(self):
        '''Plot data by sentiment (pos, neu, neg)'''
        def polarity(text):
            return TextBlob(text).sentiment.polarity
        self.data['polarity_score']=self.data[self.column].apply(lambda x : polarity(x))
        def sentiment(x):
            if x<0:
                return 'neg'
            elif x==0:
                return 'neu'
            else:
                return 'pos'
        self.data['polarity']=self.data['polarity_score'].map(lambda x: sentiment(x))
        plot = plt.bar(self.data.polarity.value_counts().index, self.data.polarity.value_counts())
        return plot
    
    def show_neg_sentiment(self):
        '''Show negative sentiment'''
        def polarity(text):
            return TextBlob(text).sentiment.polarity
        self.data['polarity_score']=self.data[self.column].apply(lambda x : polarity(x))
        def sentiment(x):
            if x<0:
                return 'neg'
            elif x==0:
                return 'neu'
            else:
                return 'pos'
        self.data['polarity']=self.data['polarity_score'].map(lambda x: sentiment(x))
        results = self.data[self.data['polarity']=='neg'][self.column].head(5)
        return results
    
    def show_pos_sentiment(self):
        '''Show positive sentiment'''
        def polarity(text):
            return TextBlob(text).sentiment.polarity
        self.data['polarity_score']=self.data[self.column].apply(lambda x : polarity(x))
        def sentiment(x):
            if x<0:
                return 'neg'
            elif x==0:
                return 'neu'
            else:
                return 'pos'
        self.data['polarity']=self.data['polarity_score'].map(lambda x: sentiment(x))
        results = self.data[self.data['polarity']=='pos'][self.column].head(5)
        return results
    
    def show_flesch_kincaid(self):
        '''show flesch kincaid score'''
        hist = self.data[self.column].apply(lambda x : flesch_reading_ease(x)).hist()
        return hist
    
    def show_bi_grams(self):
        '''show most common bi-grams'''
        corpus=[]
        new=self.data[self.column].str.split()
        new=new.values.tolist()
        corpus=[word for i in new for word in i]
        def get_top_ngram(corpus, n=None):
            vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
            bag_of_words = vec.transform(corpus)
            sum_words = bag_of_words.sum(axis=0) 
            words_freq = [(word, sum_words[0, idx]) 
                          for word, idx in vec.vocabulary_.items()]
            words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
            return words_freq[:10]

        top_n_bigrams=get_top_ngram(self.data[self.column],2)[:10]
        x,y=map(list,zip(*top_n_bigrams))
        plot = sns.barplot(x=y,y=x)
        return plot
        
    def show_tri_grams(self):
        '''show most common tri-grams'''
        corpus=[]
        new=self.data[self.column].str.split()
        new=new.values.tolist()
        corpus=[word for i in new for word in i]
        def get_top_ngram(corpus, n=None):
            vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
            bag_of_words = vec.transform(corpus)
            sum_words = bag_of_words.sum(axis=0) 
            words_freq = [(word, sum_words[0, idx]) 
                          for word, idx in vec.vocabulary_.items()]
            words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
            return words_freq[:10]

        top_n_trigrams=get_top_ngram(self.data[self.column],3)[:10]
        x,y=map(list,zip(*top_n_trigrams))
        plot = sns.barplot(x=y,y=x)
        return plot

# %%
class vizzy_token:
    def __init__(self, data, column):
        self.data = data
        self.column = column
        
    def show_labels_count(self):
        '''show count of each label'''
        labels = self.data[self.column]
        counter = Counter(labels)
        x = list(counter.keys())
        y = list(counter.values())
        plot = sns.barplot(x=y,y=x)
        return plot
    
    def print_labels_count(self):
        '''print count of each label'''
        labels = self.data[self.column]
        counter = Counter(labels)
        x = list(counter.keys())
        y = list(counter.values())
        z = zip(x,y)
        for label, count in z:
            print("Total number of {}: {}".format(label, count))

# %%
class vizzy_doc:
    def __init__(self, data, column1, column2=None, column3=None, column4=None, column5=None):
        self.data = data
        self.column1 = column1
        self.column2 = column2
        self.column3 = column3
        self.column4 = column4
        self.column5 = column5
        
    def print_doc_stats(self):
        '''Print the statistics of your document'''
        def counter(data, column):
            return data[column].nunique()
            
        docs = max(idx for idx, other in self.data.iterrows())
        print("Here is your data summary:")
        print("\n")
        print("Total number of documents: {}".format(docs))
        print("Total number of {}: {}".format(str(self.column1), (counter(self.data, self.column1))))
        if self.column2 != None:
            print("Total number of {}: {}".format(str(self.column2), (counter(self.data, self.column2))))
        else:
            pass
        if self.column3 != None:
             print("Total number of {}: {}".format(str(self.column3), (counter(self.data, self.column3))))
        else:
            pass
        if self.column4 != None:
             print("Total number of {}: {}".format(str(self.column4), (counter(self.data, self.column4))))
        else:
            pass
        if self.column5 != None:
             print("Total number of {}: {}".format(str(self.column5), (counter(self.data, self.column5))))
        else:
            pass

# %%
import spacy
import pandas as pd

nlp = spacy.load("en_core_web_sm")

text = "SpaCy is a popular library for NLP in Python. Another popular library is NLTK"
doc = nlp(text)

data = []
for token in doc:
    data.append({"Token": token.text, "Lemma": token.lemma_, "POS": token.pos_, "ENT": token.ent_type_})

df = pd.DataFrame(data)

# %%
viz = vizzy_token(df, 'POS')

# %%
viz.print_labels_count()
# Out:
# Total number of PROPN: 4
# Total number of AUX: 2
# Total number of DET: 2
# Total number of ADJ: 2
# Total number of NOUN: 2
# Total number of ADP: 2
# Total number of PUNCT: 1

# %%
# !pip install vizzy==0.1.1
# Out:
# Collecting vizzy==0.1.1
#   Downloading vizzy-0.1.1-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: wordcloud in /home/eanthony/anaconda3/lib/python3.9/site-packages (from vizzy==0.1.1) (1.8.2.2)
# Requirement already satisfied: spacy in /home/eanthony/anaconda3/lib/python3.9/site-packages (from vizzy==0.1.1) (3.5.0)
# Requirement already satisfied: sklearn in /home/eanthony/anaconda3/lib/python3.9/site-packages (from vizzy==0.1.1) (0.0.post1)
# Requirement already satisfied: pandas in /home/eanthony/anaconda3/lib/python3.9/site-packages (from vizzy==0.1.1) (1.4.4)
# Requirement already satisfied: gensim in /home/eanthony/anaconda3/lib/python3.9/site-packages (from vizzy==0.1.1) (4.1.2)
# Requirement already satisfied: matplotlib in /home/eanthony/anaconda3/lib/python3.9/site-packages (from vizzy==0.1.1) (3.5.2)
# Requirement already satisfied: nltk in /home/eanthony/anaconda3/lib/python3.9/site-packages (from vizzy==0.1.1) (3.7)
# Requirement already satisfied: numpy in /home/eanthony/anaconda3/lib/python3.9/site-packages (from vizzy==0.1.1) (1.21.5)
# Requirement already satisfied: textstat in /home/eanthony/anaconda3/lib/python3.9/site-packages (from vizzy==0.1.1) (0.7.3)
# Requirement already satisfied: textblob in /home/eanthony/anaconda3/lib/python3.9/site-packages (from vizzy==0.1.1) (0.17.1)
# Requirement already satisfied: pyldavis in /home/eanthony/anaconda3/lib/python3.9/site-packages (from vizzy==0.1.1) (3.3.1)
# Requirement already satisfied: seaborn in /home/eanthony/anaconda3/lib/python3.9/site-packages (from vizzy==0.1.1) (0.11.2)
# Requirement already satisfied: scipy>=0.18.1 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from gensim->vizzy==0.1.1) (1.9.1)
# Requirement already satisfied: smart-open>=1.8.1 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from gensim->vizzy==0.1.1) (5.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from matplotlib->vizzy==0.1.1) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from matplotlib->vizzy==0.1.1) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from matplotlib->vizzy==0.1.1) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from matplotlib->vizzy==0.1.1) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from matplotlib->vizzy==0.1.1) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from matplotlib->vizzy==0.1.1) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from matplotlib->vizzy==0.1.1) (21.3)
# Requirement already satisfied: regex>=2021.8.3 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from nltk->vizzy==0.1.1) (2022.7.9)
# Requirement already satisfied: tqdm in /home/eanthony/anaconda3/lib/python3.9/site-packages (from nltk->vizzy==0.1.1) (4.64.1)
# Requirement already satisfied: click in /home/eanthony/anaconda3/lib/python3.9/site-packages (from nltk->vizzy==0.1.1) (8.0.4)
# Requirement already satisfied: joblib in /home/eanthony/anaconda3/lib/python3.9/site-packages (from nltk->vizzy==0.1.1) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from pandas->vizzy==0.1.1) (2022.1)
# Requirement already satisfied: numexpr in /home/eanthony/anaconda3/lib/python3.9/site-packages (from pyldavis->vizzy==0.1.1) (2.8.3)
# Requirement already satisfied: jinja2 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from pyldavis->vizzy==0.1.1) (2.11.3)
# Requirement already satisfied: future in /home/eanthony/anaconda3/lib/python3.9/site-packages (from pyldavis->vizzy==0.1.1) (0.18.2)
# Requirement already satisfied: funcy in /home/eanthony/anaconda3/lib/python3.9/site-packages (from pyldavis->vizzy==0.1.1) (1.17)
# Requirement already satisfied: setuptools in /home/eanthony/.local/lib/python3.9/site-packages (from pyldavis->vizzy==0.1.1) (67.1.0)
# Requirement already satisfied: scikit-learn in /home/eanthony/anaconda3/lib/python3.9/site-packages (from pyldavis->vizzy==0.1.1) (1.0.2)
# Requirement already satisfied: pathy>=0.10.0 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from spacy->vizzy==0.1.1) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from spacy->vizzy==0.1.1) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from spacy->vizzy==0.1.1) (3.0.11)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from spacy->vizzy==0.1.1) (2.28.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from spacy->vizzy==0.1.1) (1.0.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from spacy->vizzy==0.1.1) (2.4.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from spacy->vizzy==0.1.1) (0.10.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from spacy->vizzy==0.1.1) (1.10.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from spacy->vizzy==0.1.1) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from spacy->vizzy==0.1.1) (3.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from spacy->vizzy==0.1.1) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from spacy->vizzy==0.1.1) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from spacy->vizzy==0.1.1) (8.1.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from spacy->vizzy==0.1.1) (1.0.9)
# Requirement already satisfied: pyphen in /home/eanthony/anaconda3/lib/python3.9/site-packages (from textstat->vizzy==0.1.1) (0.13.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy->vizzy==0.1.1) (4.3.0)
# Requirement already satisfied: six>=1.5 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->vizzy==0.1.1) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy->vizzy==0.1.1) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy->vizzy==0.1.1) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy->vizzy==0.1.1) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy->vizzy==0.1.1) (2022.9.14)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy->vizzy==0.1.1) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy->vizzy==0.1.1) (0.7.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from jinja2->pyldavis->vizzy==0.1.1) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/eanthony/anaconda3/lib/python3.9/site-packages (from scikit-learn->pyldavis->vizzy==0.1.1) (2.2.0)
# Installing collected packages: vizzy
#   Attempting uninstall: vizzy
#     Found existing installation: vizzy 0.1.0
#     Uninstalling vizzy-0.1.0:
#       Successfully uninstalled vizzy-0.1.0
# Successfully installed vizzy-0.1.1

# %%
from vizzy import vizzy

# %%
viz = vizzy.vizzy_token(df, 'POS')

# %%
viz.print_labels_count()
# Out:
# Total number of propn: 4
# Total number of aux: 2
# Total number of det: 2
# Total number of adj: 2
# Total number of noun: 2
# Total number of adp: 2
# Total number of punct: 1
